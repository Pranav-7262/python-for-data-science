# %%
f = open("example.txt" , "w")
f.write("\nwelcome to my world")
# Out:
# 20

# %%
f = open("example.txt" , "r")
print(f.read())
# Out:
# welcome to my world

# %%
f = open("example.txt" , "a")
f.write("\nwelcome to my college")
# Out:
# 22

# %%
f = open("example.txt" , "r")
print(f.read())
# Out:
# welcome to my world
# welcome to my college

# %%
# f.close()
f = open("example.txt" , "r")
print(f.readlines())
# Out:
# ['\n', 'welcome to my world\n', 'welcome to my college']

# %%
file = open(r"C:\Users\dell\OneDrive\Desktop\demo.txt", "r")
print(file.read())
# Out:
# hi my name is Pranav !

# %%
file = open(r"C:\Users\dell\OneDrive\Desktop\demo.txt" , "w")
file.write("\nwelcome to my world")
# Out:
# 20

# %%
file = open(r"C:\Users\dell\OneDrive\Desktop\demo.txt" , "r")
print(file.read())
# Out:
# welcome to my world

# %%
file = open(r"C:\Users\dell\OneDrive\Desktop\demo.txt" , "a")
file.write("\nHello From Pranav")
# Out:
# 18

# %%
file = open(r"C:\Users\dell\OneDrive\Desktop\demo.txt" , "r")
print(file.read())
# Out:
# welcome to my world
# Hello From Pranav
