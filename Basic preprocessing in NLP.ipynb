# %%
# !pip install nltk

# %%
import nltk

# %%
text = """ Mahur (Mahurgad) – The Spiritual Capital of Nanded District

Mahur is a famous pilgrimage town located about 130 km from Nanded. It is best known for the Renuka Devi Temple, one of Maharashtra's most revered Shakti Peethas and a major religious destination for Hindus.

Why is Mahur famous?
1. Renuka Devi Temple

Renuka Devi Temple is dedicated to Goddess Renuka, the mother of Lord Parashurama (the sixth incarnation of Vishnu). The temple sits atop a hill surrounded by forests and scenic landscapes. It is believed to be around 800–900 years old and was constructed during the Yadava period.

2. One of the Important Shakti Peethas

According to Hindu tradition, Mahur is considered a sacred Shakti Peetha. Legends associate the site with Goddess Sati and Goddess Renuka, making it a highly significant center of Shakti worship. Thousands of devotees visit during Navratri and Dussehra.

3. Dattatreya Temple (Datta Shikhar)

Datta Shikhar is another major attraction. It is believed to be one of the important places associated with Lord Dattatreya, attracting devotees from Maharashtra, Telangana, and Karnataka.

4. Anusuya Mata Temple

Anusuya Mata Temple is dedicated to Mata Anusuya, mother of Lord Dattatreya. Many pilgrims visit all three temples—Renuka Devi, Datta Shikhar, and Anusuya Mata—in a single pilgrimage.

5. Mahur Fort

Mahur Fort is a historic hill fort located near the temple complex. The fort offers panoramic views of the surrounding forests and has historical connections to several dynasties, including the Gond rulers and the Nizams. """

# %% [markdown]
# ## 1.Tokenization

# %%
from nltk.tokenize import sent_tokenize,word_tokenize

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
word_tokens = word_tokenize(text)
word_tokens
# Out:
# ['Mahur',
#  '(',
#  'Mahurgad',
#  ')',
#  '–',
#  'The',
#  'Spiritual',
#  'Capital',
#  'of',
#  'Nanded',
#  'District',
#  'Mahur',
#  'is',
#  'a',
#  'famous',
#  'pilgrimage',
#  'town',
#  'located',
#  'about',
#  '130',
#  'km',
#  'from',
#  'Nanded',
#  '.',
#  'It',
#  'is',
#  'best',
#  'known',
#  'for',
#  'the',
#  'Renuka',
#  'Devi',
#  'Temple',
#  ',',
#  'one',
#  'of',
#  'Maharashtra',
#  "'s",
#  'most',
#  'revered',
#  'Shakti',
#  'Peethas',
#  'and',
#  'a',
#  'major',
#  'religious',
#  'destination',
#  'for',
#  'Hindus',
#  '.',
#  'Why',
#  'is',
#  'Mahur',
#  'famous',
#  '?',
#  '1',
#  '.',
#  'Renuka',
#  'Devi',
#  'Temple',
#  'Renuka',
#  'Devi',
#  'Temple',
#  'is',
#  'dedicated',
#  'to',
#  'Goddess',
#  'Renuka',
#  ',',
#  'the',
#  'mother',
#  'of',
#  'Lord',
#  'Parashurama',
#  '(',
#  'the',
#  'sixth',
#  'incarnation',
#  'of',
#  'Vishnu',
#  ')',
#  '.',
#  'The',
#  'temple',
#  'sits',
#  'atop',
#  'a',
#  'hill',
# ...

# %%
sent_token = sent_tokenize(text)
sent_token
# Out:
# [' Mahur (Mahurgad) – The Spiritual Capital of Nanded District\n\nMahur is a famous pilgrimage town located about 130 km from Nanded.',
#  "It is best known for the Renuka Devi Temple, one of Maharashtra's most revered Shakti Peethas and a major religious destination for Hindus.",
#  'Why is Mahur famous?',
#  '1.',
#  'Renuka Devi Temple\n\nRenuka Devi Temple is dedicated to Goddess Renuka, the mother of Lord Parashurama (the sixth incarnation of Vishnu).',
#  'The temple sits atop a hill surrounded by forests and scenic landscapes.',
#  'It is believed to be around 800–900 years old and was constructed during the Yadava period.',
#  '2.',
#  'One of the Important Shakti Peethas\n\nAccording to Hindu tradition, Mahur is considered a sacred Shakti Peetha.',
#  'Legends associate the site with Goddess Sati and Goddess Renuka, making it a highly significant center of Shakti worship.',
#  'Thousands of devotees visit during Navratri and Dussehra.',
#  '3.',
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# ## 2. Cleaning

# %%
from string import punctuation

# %%
text = "'Mahur Fort\n\nMahur Fort is @#$%^^&&&---a historic hill fort located near the temple complex.',"
word_token = word_tokenize(text)
word_token
# Out:
# ["'Mahur",
#  'Fort',
#  'Mahur',
#  'Fort',
#  'is',
#  '@',
#  '#',
#  '$',
#  '%',
#  '^^',
#  '&',
#  '&',
#  '&',
#  '--',
#  '-a',
#  'historic',
#  'hill',
#  'fort',
#  'located',
#  'near',
#  'the',
#  'temple',
#  'complex',
#  '.',
#  "'",
#  ',']

# %%
clean_data = [i for i in word_token if i not in punctuation]
clean_data
# Out:
# ["'Mahur",
#  'Fort',
#  'Mahur',
#  'Fort',
#  'is',
#  '^^',
#  '--',
#  '-a',
#  'historic',
#  'hill',
#  'fort',
#  'located',
#  'near',
#  'the',
#  'temple',
#  'complex']

# %%
text = " Mahur is a famous pilgrimage <> @ # $ % & town located about 130 km from Nanded. @# It is best known for the Renuka Devi Temple, one of Maharashtra's most revered Shakti Peethas and a major religious destination for Hindus. "
sent_tokens = sent_tokenize(text)
sent_tokens
# Out:
# [' Mahur is a famous pilgrimage <> @ # $ % & town located about 130 km from Nanded.',
#  "@# It is best known for the Renuka Devi Temple, one of Maharashtra's most revered Shakti Peethas and a major religious destination for Hindus."]

# %%
clean_data1 = [i for i in sent_tokens if i not in punctuation]
clean_data1
# Out:
# [' Mahur is a famous pilgrimage <> @ # $ % & town located about 130 km from Nanded.',
#  "@# It is best known for the Renuka Devi Temple, one of Maharashtra's most revered Shakti Peethas and a major religious destination for Hindus."]

# %% [markdown]
# ### 3.Normalization

# %% [markdown]
# ## 4.StopWords removal

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords.words("english")[:50]
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn']

# %%
total_count = stopwords.fileids()
total_count
# Out:
# ['albanian',
#  'arabic',
#  'azerbaijani',
#  'basque',
#  'belarusian',
#  'bengali',
#  'catalan',
#  'chinese',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'greek',
#  'hebrew',
#  'hinglish',
#  'hungarian',
#  'indonesian',
#  'italian',
#  'kazakh',
#  'nepali',
#  'norwegian',
#  'portuguese',
#  'romanian',
#  'russian',
#  'slovene',
#  'spanish',
#  'swedish',
#  'tajik',
#  'tamil',
#  'turkish',
#  'uzbek']

# %%
len(total_count)
# Out:
# 33

# %%
stop = stopwords.words("english")
stop
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
text = "Mahur is a famous pilgrimage town located about 130 km from Nanded. It is best known for the Renuka Devi Temple, one of Maharashtra's most revered Shakti Peethas and a major religious destination for Hindus."
text1 = word_tokenize(text)
text1
# Out:
# ['Mahur',
#  'is',
#  'a',
#  'famous',
#  'pilgrimage',
#  'town',
#  'located',
#  'about',
#  '130',
#  'km',
#  'from',
#  'Nanded',
#  '.',
#  'It',
#  'is',
#  'best',
#  'known',
#  'for',
#  'the',
#  'Renuka',
#  'Devi',
#  'Temple',
#  ',',
#  'one',
#  'of',
#  'Maharashtra',
#  "'s",
#  'most',
#  'revered',
#  'Shakti',
#  'Peethas',
#  'and',
#  'a',
#  'major',
#  'religious',
#  'destination',
#  'for',
#  'Hindus',
#  '.']

# %%
stopword_removed = [i for i in text1 if i not in stop]
stopword_removed
# Out:
# ['Mahur',
#  'famous',
#  'pilgrimage',
#  'town',
#  'located',
#  '130',
#  'km',
#  'Nanded',
#  '.',
#  'It',
#  'best',
#  'known',
#  'Renuka',
#  'Devi',
#  'Temple',
#  ',',
#  'one',
#  'Maharashtra',
#  "'s",
#  'revered',
#  'Shakti',
#  'Peethas',
#  'major',
#  'religious',
#  'destination',
#  'Hindus',
#  '.']

# %%
stop_in_marathi = stopwords.words("french")
stop
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
# ...

# %%
text3 = "Je suis étudiant en science des données. tenhamos"
text4 = word_tokenize(text3)
text4
# Out:
# ['Je', 'suis', 'étudiant', 'en', 'science', 'des', 'données', '.', 'tenhamos']

# %%
removed = [i for i in text4 if i not in stop]
removed
# Out:
# ['Je', 'suis', 'étudiant', 'en', 'science', 'des', 'données', '.', 'tenhamos']

# %%
marathi_stopwords = [
    "आहे", "आणि", "मध्ये", "वर", "च्या", "ची", "चे",
    "तो", "ती", "ते", "हा", "ही", "हे",
    "मी", "तू", "आम्ही", "तुम्ही",
    "एक", "दोन", "किंवा", "पण", "जर",
    "नाही", "हो", "तर", "म्हणून"
]

# %%
from nltk.tokenize import word_tokenize

text = "महूर हे महाराष्ट्रातील एक प्रसिद्ध तीर्थक्षेत्र आहे"

tokens = word_tokenize(text)

clean_tokens = [word for word in tokens if word not in marathi_stopwords]

print(clean_tokens)
# Out:
# ['महूर', 'महाराष्ट्रातील', 'प्रसिद्ध', 'तीर्थक्षेत्र']

# %% [markdown]
# ### 5.1 Stemming

# %%
from nltk.stem import LancasterStemmer
import re

lancaster = LancasterStemmer()

text = """NLTK does not provide Marathi stopwords by default. We typically create a custom Marathi stopword list or use publicly available Marathi stopword datasets. After tokenization, we filter tokens that appear in the stopword list before applying stemming, lemmatization, or feature extraction techniques such as TF-IDF."""

words = re.findall(r'\b\w+\b',text)

stemmed_words = [lancaster.stem(i) for i in words]

print("Original words: ",words)
print("Stemmed words: ",stemmed_words)
# Out:
# Original words:  ['NLTK', 'does', 'not', 'provide', 'Marathi', 'stopwords', 'by', 'default', 'We', 'typically', 'create', 'a', 'custom', 'Marathi', 'stopword', 'list', 'or', 'use', 'publicly', 'available', 'Marathi', 'stopword', 'datasets', 'After', 'tokenization', 'we', 'filter', 'tokens', 'that', 'appear', 'in', 'the', 'stopword', 'list', 'before', 'applying', 'stemming', 'lemmatization', 'or', 'feature', 'extraction', 'techniques', 'such', 'as', 'TF', 'IDF']
# Stemmed words:  ['nltk', 'doe', 'not', 'provid', 'marath', 'stopword', 'by', 'default', 'we', 'typ', 'cre', 'a', 'custom', 'marath', 'stopword', 'list', 'or', 'us', 'publ', 'avail', 'marath', 'stopword', 'dataset', 'aft', 'tok', 'we', 'filt', 'tok', 'that', 'appear', 'in', 'the', 'stopword', 'list', 'bef', 'apply', 'stem', 'lem', 'or', 'feat', 'extract', 'techn', 'such', 'as', 'tf', 'idf']

# %%
text1 = """NLTK does not provide englihhhhhhh stopwords by default. We typically create a custom Marathi stopword list or use publicly available Marathi stopword datasets. After tokenization, we filter tokens that appear in the stopword list before applying stemming, lemmatization, or feature extraction techniques such as TF-IDF."""

words1 = re.findall(r'\b\w+\b',text1)

stemmed_words = [lancaster.stem(i) for i in words1]

print("Original words: ",words1)
print("Stemmed words: ",stemmed_words)
# Out:
# Original words:  ['NLTK', 'does', 'not', 'provide', 'englihhhhhhh', 'stopwords', 'by', 'default', 'We', 'typically', 'create', 'a', 'custom', 'Marathi', 'stopword', 'list', 'or', 'use', 'publicly', 'available', 'Marathi', 'stopword', 'datasets', 'After', 'tokenization', 'we', 'filter', 'tokens', 'that', 'appear', 'in', 'the', 'stopword', 'list', 'before', 'applying', 'stemming', 'lemmatization', 'or', 'feature', 'extraction', 'techniques', 'such', 'as', 'TF', 'IDF']
# Stemmed words:  ['nltk', 'doe', 'not', 'provid', 'englihhhhhhh', 'stopword', 'by', 'default', 'we', 'typ', 'cre', 'a', 'custom', 'marath', 'stopword', 'list', 'or', 'us', 'publ', 'avail', 'marath', 'stopword', 'dataset', 'aft', 'tok', 'we', 'filt', 'tok', 'that', 'appear', 'in', 'the', 'stopword', 'list', 'bef', 'apply', 'stem', 'lem', 'or', 'feat', 'extract', 'techn', 'such', 'as', 'tf', 'idf']

# %% [markdown]
# ### 5.2 Lemmatization

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
import nltk

#nltk.download('wordnet')
#nltk.download('punkt')

lemmatizer = WordNetLemmatizer()

sentence = "NLTK does not provide Marathi stopwords by default. We typically create a custom Marathi stopword list or use publicly available Marathi stopword datasets. After tokenization, we filter tokens that appear in the stopword list before applying stemming, lemmatization, or feature extraction techniques such as TF-IDF."

words = word_tokenize(sentence.lower())

lemmatized_words = [lemmatizer.lemmatize(word,pos="v") for word in words]

print("\n Original Sentence: \n\n",sentence)
print("\n Stemmed Sentence: \n\n", " ".join(stemmed_words))
print("\n Lemmatized Sentence: \n\n", " ".join(lemmatized_words))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\nltk\corpus\util.py:84, in LazyCorpusLoader.__load(self)
#      83 try:
# ---> 84     root = nltk.data.find(f"{self.subdir}/{zip_name}")
#      85 except LookupError:
#
# File ~\anaconda3\Lib\site-packages\nltk\data.py:579, in find(resource_name, paths)
#     578 resource_not_found = f"\n{sep}\n{msg}\n{sep}\n"
# --> 579 raise LookupError(resource_not_found)
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - 'C:\\Users\\dell/nltk_data'
# ...

# %% [markdown]
# # Summary of NLP Pipeline
# ## Tokenization       --->  Splits text into words or sentences
# ## Cleaning           ---> Removes punctuation and noise
# ## Stopword Removal   ---> Removes common, meaningless words
# ## Stemming           ---> Aggressively cuts word endings
# ## Lemmatization      ---> Reduces words to their proper base form
