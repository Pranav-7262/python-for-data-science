# %%
import pandas as pd
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Sort a DF

# %%
df.sort_values(by='math score')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 59   female        group C            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# 787  female        group B                some college      standard
# 145  female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 625    male        group D                some college      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# 962  female        group E          associate's degree      standard
# 149    male        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values(by='math score' , ascending=False)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 458  female        group E           bachelor's degree      standard
# 623    male        group A                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values(['math score','writing score'] , ascending=False , inplace=True)

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
df.sort_values("race/ethnicity" , ascending=True, key=lambda col:col.str.lower())
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 402  female        group A                some college  free/reduced
# 960  female        group A                some college      standard
# 994    male        group A                 high school      standard
# 61     male        group A            some high school  free/reduced
# 586  female        group A                 high school      standard
# ..      ...            ...                         ...           ...
# 915  female        group E                some college      standard
# 751    male        group E                some college      standard
# 592    male        group E           bachelor's degree      standard
# 499    male        group E                some college      standard
# 517  female        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Create Index

# %%
import numpy as np
import random

# %%
new_idx = np.arange(0,1000)

# %%
random.shuffle(new_idx)

# %%
df["new_index"] = new_idx
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 458  female        group E           bachelor's degree      standard
# 916    male        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 625    male        group D                some college      standard
# 451  female        group E                some college      standard
# ..      ...            ...                         ...           ...
# 145  female        group C                some college  free/reduced
# 787  female        group B                some college      standard
# 17   female        group B            some high school  free/reduced
# 980  female        group B                 high school  free/reduced
# 59   female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
df.set_index('new_index' , inplace=True) # set index

# %%
df
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 211        female        group E           bachelor's degree      standard
# 9            male        group E           bachelor's degree      standard
# 300        female        group E          associate's degree      standard
# 547          male        group D                some college      standard
# 686        female        group E                some college      standard
# ...           ...            ...                         ...           ...
# 285        female        group C                some college  free/reduced
# 20         female        group B                some college      standard
# 317        female        group B            some high school  free/reduced
# 865        female        group B                 high school  free/reduced
# 744        female        group C            some high school  free/reduced
#
# ...

# %%
df.sort_index(inplace=True)   # Sort index

# %%
df
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# new_index
# 0          female        group C          associate's degree      standard
# 1          female        group C             master's degree      standard
# 2            male        group D                some college      standard
# 3          female        group C                 high school      standard
# 4          female        group E                 high school      standard
# ...           ...            ...                         ...           ...
# 995          male        group C                 high school      standard
# 996        female        group B                 high school  free/reduced
# 997        female        group B            some high school      standard
# 998          male        group C                 high school      standard
# 999          male        group E          associate's degree  free/reduced
#
# ...
