# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # Syntax 1

# %%
df["lunch"]
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %%
type(df["lunch"])
# Out:
# pandas.core.series.Series

# %%
df["lunch"].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df["lunch"].head(5)
# Out:
# 0        standard
# 1        standard
# 2        standard
# 3    free/reduced
# 4        standard
# Name: lunch, dtype: object

# %% [markdown]
# # Syntax 2

# %%
df.lunch
# Out:
# 0          standard
# 1          standard
# 2          standard
# 3      free/reduced
# 4          standard
#            ...
# 995        standard
# 996    free/reduced
# 997    free/reduced
# 998        standard
# 999    free/reduced
# Name: lunch, Length: 1000, dtype: object

# %% [markdown]
# # Selecting more columns

# %%
df[["gender" , "lunch"]]
# Out:
#      gender         lunch
# 0    female      standard
# 1    female      standard
# 2    female      standard
# 3      male  free/reduced
# 4      male      standard
# ..      ...           ...
# 995  female      standard
# 996    male  free/reduced
# 997  female  free/reduced
# 998  female      standard
# 999  female  free/reduced
#
# [1000 rows x 2 columns]

# %%
type(df[["gender" , "lunch"]])
# Out:
# pandas.core.frame.DataFrame

# %%
df[["gender" , "lunch" , "math score"]]
# Out:
#      gender         lunch  math score
# 0    female      standard          72
# 1    female      standard          69
# 2    female      standard          90
# 3      male  free/reduced          47
# 4      male      standard          76
# ..      ...           ...         ...
# 995  female      standard          88
# 996    male  free/reduced          62
# 997  female  free/reduced          59
# 998  female      standard          68
# 999  female  free/reduced          77
#
# [1000 rows x 3 columns]

# %% [markdown]
# # Adding new Column

# %%
df["lang score"] = 80 # Scalar value
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %% [markdown]
# # With Arrays add new col

# %%
import numpy as np

# %%
score = np.arange(0 , 1000)

# %%
len(score)
# Out:
# 1000

# %%
df["lang score"] = score

# %%
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
rand_score = np.random.randint(1 , 100 , size=1000)
len(rand_score)
# Out:
# 1000

# %%
min(rand_score)
# Out:
# np.int32(1)

# %%
max(rand_score)
# Out:
# np.int32(99)

# %%
df["lang score"] = rand_score
df
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
# create a float numbers
np.random.uniform(1 , 100 , size=100)
# Out:
# array([25.86897415, 21.73170079, 64.2527686 , 79.24392381, 99.16887147,
#        47.15958538,  3.74164885,  1.79657369, 55.83946357, 82.58640333,
#        72.27354155, 41.12151286, 39.22422977, 45.00473271, 89.02405811,
#        97.06887041, 18.49896002, 20.68978999, 90.71844904, 47.40313018,
#        84.50630698, 72.02639111, 80.89202945, 22.84410223, 49.3488226 ,
#        18.680815  , 46.62381826, 91.8161104 , 28.0936306 , 59.89154083,
#        15.6233395 , 93.20019103, 63.82659777, 59.72434901, 37.15085142,
#        70.57993628, 78.63733381, 97.54514897, 22.43324433,  5.93678926,
#        44.38304668, 47.63524879, 82.73821745, 45.48357386, 63.16676644,
#        67.64296583, 78.68890916, 23.30085588, 64.90632634, 98.16460024,
#        96.58037559, 65.11092789,  5.87028021, 11.38463567, 52.04454635,
#        23.02142978, 40.9414258 , 17.93181559, 23.50889579, 98.23154311,
#         4.93121618, 42.94856644, 78.96392458, 92.06107257, 88.27220484,
# ...

# %%
score_1 = np.random.randint(1 , 100 , size=1000)
score_2 = np.random.randint(1 , 100 , size=1000)
series1 = pd.Series(score_1 , index=np.arange(0,1000))
series2 = pd.Series(score_2 , index=np.arange(0,1000))

# %%
series1
# Out:
# 0       9
# 1      43
# 2      37
# 3       9
# 4      98
#        ..
# 995     5
# 996    37
# 997    55
# 998    94
# 999    55
# Length: 1000, dtype: int32

# %%
df.assign(score1 = score_1 , score2 = score_2)  # Using assign method
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female     9        group B           bachelor's degree      standard
# 1    female    43        group C                some college      standard
# 2    female    37        group B             master's degree      standard
# 3      male     9        group A          associate's degree  free/reduced
# 4      male    98        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 995  female     5        group E             master's degree      standard
# 996    male    37        group C                 high school  free/reduced
# 997  female    55        group C                 high school  free/reduced
# 998  female    94        group D                some college      standard
# 999  female    55        group D                some college  free/reduced
#
# ...

# %%
df.insert(1,"test2", series1)

# %%
df
# Out:
#      gender  test2  test race/ethnicity parental level of education  \
# 0    female      9     9        group B           bachelor's degree
# 1    female     43    43        group C                some college
# 2    female     37    37        group B             master's degree
# 3      male      9     9        group A          associate's degree
# 4      male     98    98        group C                some college
# ..      ...    ...   ...            ...                         ...
# 995  female      5     5        group E             master's degree
# 996    male     37    37        group C                 high school
# 997  female     55    55        group C                 high school
# 998  female     94    94        group D                some college
# 999  female     55    55        group D                some college
#
#             lunch test preparation course  math score  reading score  \
# 0        standard                    none          72             72
# ...
